# %% [markdown]
# <a href="https://colab.research.google.com/github/cshuler/DL_watershed/blob/master/Scripts/testout1p2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import keras
import pandas as pd

# %%
# Clone DL repo.
# !git clone -l -s git://github.com/cshuler/DL_watershed cloned-repo
# %cd cloned-repo
# note that repo is cloned. Files saved will save to temprary space if in google colab
#i.e. try not to save anything
# Out:
# Cloning into 'cloned-repo'...
# warning: --local is ignored
# remote: Enumerating objects: 4339, done.
# remote: Counting objects: 100% (4339/4339), done.
# remote: Compressing objects: 100% (378/378), done.
# remote: Total 4339 (delta 3929), reused 4338 (delta 3928), pack-reused 0
# Receiving objects: 100% (4339/4339), 35.56 MiB | 25.20 MiB/s, done.
# Resolving deltas: 100% (3929/3929), done.
# Checking out files: 100% (4404/4404), done.
# /content/cloned-repo

# %% [markdown]
# # load up data files

# %%
# import precip data
preciprawdata = pd.read_csv(os.path.join('Raw_Data_tutuila', 'Olkeba_data', 'LBJ_Precip_mm.csv' ), index_col=0,parse_dates=True)

#import flow data
LBJflowrawdata = pd.read_csv(os.path.join('Raw_Data_tutuila', 'Olkeba_data', 'LBJ_Alex_Q_CFSs.csv'), index_col=0, parse_dates=True)
LBJflowrawdata = LBJflowrawdata.resample('D').mean()     # subsample the 15 min data into daily values

# %%
mergeddata = pd.merge(preciprawdata, LBJflowrawdata, how='inner', left_index=True, right_index=True)

# %%
mergeddata.plot(figsize = (15, 6))

# %%
unbroken_data = mergeddata.dropna()       # remove any rows where there is no data (a gap)

# %%
unbroken_data.plot(figsize = (15, 6))
